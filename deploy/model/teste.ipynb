# %%
import pickle

# %%
file = 'C:/Users/hp/Desktop/Credit Card Fraud Detection Project/deploy/model/final_model.pkl'

# %%
with open(file, 'rb') as f:
    infos_loaded = pickle.load(f)
    print(infos_loaded)
# Out:
# RandomForestClassifier(n_estimators=200, random_state=42)
